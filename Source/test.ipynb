# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
img = np.loadtxt("Values1.txt", delimiter=', ')
img = img.astype(np.uint8)
img = img.reshape(64, 64)
plt.imshow(img, cmap='gray')

# %%
img = img.astype(np.uint8)
img = img.reshape(1024, 1024)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f2a555a3a423> in <module>
#       1 img = img.astype(np.uint8)
# ----> 2 img = img.reshape(1024, 1024)
#
# ValueError: cannot reshape array of size 4096 into shape (1024,1024)

# %%
plt.imshow(img, cmap='gray')

# %%
byte = b''

# %%
import imutils
img = np.frombuffer(byte, np.uint8)
img = img.reshape(64, 64)
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
img = cv2.resize(img, (28, 28), interpolation = cv2.INTER_AREA)
#img = image_resize(img, 28, 28, 3)
plt.subplot(1,2,2)
plt.imshow(img, cmap='gray')
#cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def image_resize(image, width = None, height = None, inter = cv2.INTER_AREA):
    # initialize the dimensions of the image to be resized and
    # grab the image size
    dim = None
    (h, w) = image.shape[:2]

    # if both the width and height are None, then return the
    # original image
    if width is None and height is None:
        return image

    # check to see if the width is None
    if width is None:
        # calculate the ratio of the height and construct the
        # dimensions
        r = height / float(h)
        dim = (int(w * r), height)

    # otherwise, the height is None
    else:
        # calculate the ratio of the width and construct the
        # dimensions
        r = width / float(w)
        dim = (width, int(h * r))

    # resize the image
    resized = cv2.resize(image, dim, interpolation = inter)

    # return the resized image
    return resized

# %%
import tensorflow as tf
import tensorflow.keras as keras
mnist = keras.datasets.mnist.load_data()
(X_train, y_train), (X_test, y_test) = mnist
# X_train = X_train.astype("float16") / 255
# X_test = X_test.astype("float16") / 255
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
plt.imshow(X_train[321].reshape(28,28), cmap='gray')
